# %%
# Install necessary libraries
# !pip install -q faiss-cpu google-generativeai wordcloud matplotlib requests

# %%
serp_api_key = input("Enter your SerpAPI Key: ")
gemini_api_key = input("Enter your Gemini API Key: ")
# Out:
# Enter your SerpAPI Key: f3661376f24a7f33d3d2cd8b7e064cc4d6db646efe60e8831c81f769e11b0788
# Enter your Gemini API Key: AIzaSyDgRIkZ-MD74Ox5UMFf6QB4SeMQZqtbxm0

# %%
#  Inputs from user
import json
from datetime import datetime, timedelta


industry = input("Enter Industry (Default: Mobile Phone Manufacturing): ") or "Mobile Phone Manufacturing"
topic = input("Enter Topic (e.g. Foldable Displays, Battery Tech, etc.): ") or "Battery Technology"
# Out:
# Enter Industry (Default: Mobile Phone Manufacturing):
# Enter Topic (e.g. Foldable Displays, Battery Tech, etc.):

# %%
# 📦 Import required libraries
import requests
import pprint
from datetime import datetime, timedelta
import json
from dateutil import parser  # Helps parse messy date strings

#  Agent 1: PatentFetcher
class PatentFetcher:
    def __init__(self, api_key):
        self.api_key = api_key  # Save the SerpAPI key

    def fetch(self, industry, topic):
        # Define the API endpoint and search parameters
        url = "https://serpapi.com/search"
        params = {
            "engine": "google_patents",
            "q": f"{topic} {industry}",
            "hl": "en",
            "api_key": self.api_key,
            "num": 50  # Try to fetch up to 50 results
        }

        # Make the GET request to SerpAPI
        response = requests.get(url, params=params)
        data = response.json()

        patents = []
        for i, item in enumerate(data.get("organic_results", [])):
            # Print first 3 patent items for structure inspection
            if i < 3:
                print(f"--- Item {i + 1} ---")
                pprint.pprint(item)

            # Try to parse the publication date
            date_str = item.get("publication_date")
            try:
                publication_date = parser.parse(date_str).date() if date_str else None
            except ValueError:
                publication_date = None  # If parsing fails, skip date

            # Extract relevant patent info
            patents.append({
                "title": item.get("title", ""),
                "abstract": item.get("snippet", ""),
                "assignee": item.get("assignee", ""),  # ✅ Try to extract assignee (correct field name)
                "keywords": topic.lower().split(),
                "publication_date": publication_date  # Stored as date object
            })

        # Filter patents from the last 90 days only
        cutoff = datetime.now().date() - timedelta(days=360)
        filtered_patents = [
            p for p in patents if p["publication_date"] and p["publication_date"] >= cutoff

        ]

        # If you want to see the patents that didn't pass the filter:
        for patent in patents:
            if not patent["publication_date"] or patent["publication_date"] < cutoff:
                print(f"Skipping: {patent['title']} with date {patent['publication_date']}")

        return filtered_patents  # Return filtered patents instead of all patents


#  Get user inputs and run fetcher
serp_api_key = input("Enter your SerpAPI Key: ")
industry = input("Enter Industry: ") or "Mobile Phone Manufacturing"
topic = input("Enter Topic: ") or "Battery Technology"

#  Instantiate the PatentFetcher agent and fetch data
fetcher = PatentFetcher(serp_api_key)
all_patents = fetcher.fetch(industry, topic)

# Filter only patents that have valid publication dates
filtered_patents = [p for p in all_patents if p["publication_date"]]


#  Save filtered patents to JSON file
with open("patents.json", "w") as f:
    for patent in filtered_patents:
        # Convert datetime.date to ISO string for JSON
        if patent["publication_date"]:
            patent["publication_date"] = patent["publication_date"].isoformat()
    json.dump(filtered_patents, f, indent=4)

#  Final output
print(f"{len(filtered_patents)} recent patents saved to patents.json")
# Out:
# Enter your SerpAPI Key: ce12685cace21890b9f30bf40bedfc7ebaff073cee1210567f1e15c1440d0846
# Enter Industry:
# Enter Topic:
# --- Item 1 ---
# {'assignee': 'Motorola, Inc.',
#  'country_status': {'US': 'NOT_ACTIVE'},
#  'figures': [{'full': 'https://patentimages.storage.googleapis.com/2d/6a/7d/30e12fff104fc6/US20090023480A1-20090122-D00000.png',
#               'thumbnail': 'https://patentimages.storage.googleapis.com/04/7a/a9/d787edff08a83a/US20090023480A1-20090122-D00000.png'},
#              {'full': 'https://patentimages.storage.googleapis.com/15/7a/ea/951944281b8b25/US20090023480A1-20090122-D00001.png',
#               'thumbnail': 'https://patentimages.storage.googleapis.com/9c/35/ad/b88920023f9056/US20090023480A1-20090122-D00001.png'},
#              {'full': 'https://patentimages.storage.googleapis.com/c1/6c/e2/b9178f3dae1f3f/US20090023480A1-20090122-D00002.png',
#               'thumbnail': 'https://patentimages.storage.googleapis.com/01/02/43/02d50cfb5c9b14/US20090023480A1-20090122-D00002.png'},
#              {'full': 'https://patentimages.storage.googleapis.com/66/bc/80/770a04b1aea06c/US20090023480A1-20090122-D00003.png',
#               'thumbnail': 'https://patentimages.storage.googleapis.com/3f/1d/cc/1038dd6ab6456a/US20090023480A1-20090122-D00003.png'},
#              {'full': 'https://patentimages.storage.googleapis.com/3f/20/02/361f506642c02c/US20090023480A1-20090122-D00004.png',
#               'thumbnail': 'https://patentimages.storage.googleapis.com/61/c1/76/1a2dded46ae230/US20090023480A1-20090122-D00004.png'},
#              {'full': 'https://patentimages.storage.googleapis.com/73/1a/35/36e55cd296a84f/US20090023480A1-20090122-D00005.png',
#               'thumbnail': 'https://patentimages.storage.googleapis.com/91/19/a4/c482c1c5433f77/US20090023480A1-20090122-D00005.png'},
#              {'full': 'https://patentimages.storage.googleapis.com/e8/07/bf/1df487e3069c33/US20090023480A1-20090122-D00006.png',
#               'thumbnail': 'https://patentimages.storage.googleapis.com/4b/d2/99/bb4e44f8076849/US20090023480A1-20090122-D00006.png'}],
#  'filing_date': '2007-07-17',
#  'inventor': 'Ajoy Nandi',
#  'language': 'en',
#  'patent_id': 'patent/US20090023480A1/en',
#  'patent_link': 'https://patents.google.com/patent/US20090023480A1/en',
#  'pdf': 'https://patentimages.storage.googleapis.com/79/3c/3e/aeb8dbb4db068f/US20090023480A1.pdf',
#  'position': 1,
#  'priority_date': '2007-07-17',
#  'publication_date': '2009-01-22',
#  'publication_number': 'US20090023480A1',
#  'rank': 0,
#  'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FUS20090023480A1%2Fen',
#  'snippet': 'A system comprises a first wireless communication device, a '
#             'second wireless communication device. The first wireless '
#             'communication device comprises a first male connector and a first '
#             'female connector. The second wireless communication device '
#             'comprises a second male connector and a second female …',
#  'thumbnail': 'https://patentimages.storage.googleapis.com/37/52/8a/5635cd74753b82/US20090023480A1-20090122-D00000.png',
#  'title': 'System and apparatus for device to device charging'}
# --- Item 2 ---
# {'assignee': '吕忠岩',
#  'country_status': {'CN': 'NOT_ACTIVE'},
#  'figures': [{'full': 'https://patentimages.storage.googleapis.com/a0/97/84/d4a7f0dac421ec/DEST_PATH_HSB00000731542200011.png',
#               'thumbnail': 'https://patentimages.storage.googleapis.com/c1/72/1f/66f970b4142cfc/DEST_PATH_HSB00000731542200011.png'}],
#  'filing_date': '2011-08-26',
#  'grant_date': '2012-04-25',
#  'inventor': '吕忠岩',
#  'language': 'en',
#  'patent_id': 'patent/CN202206553U/en',
#  'patent_link': 'https://patents.google.com/patent/CN202206553U/en',
#  'pdf': 'https://patentimages.storage.googleapis.com/72/ea/53/a83a3e86336b02/CN202206553U.pdf',
#  'position': 2,
#  'priority_date': '2011-08-26',
#  'publication_date': '2012-04-25',
#  'publication_number': 'CN202206553U',
#  'rank': 1,
#  'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FCN202206553U%2Fen',
#  'snippet': 'The utility model discloses a personal base station of a mobile '
#             'phone, and the personal base station can be used for reducing the '
#             'power radiation of the mobile phone. A power module communicated '
#             'wirelessly with a cell base station in an original mobile phone '
#             'is shifted into the personal base …',
#  'thumbnail': 'https://patentimages.storage.googleapis.com/67/d3/30/42ae2c8bc9229a/DEST_PATH_HSB00000731542200011.png',
#  'title': 'Personal base station of mobile phone'}
# --- Item 3 ---
# {'assignee': '慕威尔图有限公司',
#  'country_status': {'CN': 'ACTIVE',
#                     'EP': 'NOT_ACTIVE',
#                     'US': 'NOT_ACTIVE',
#                     'WO': 'ACTIVE'},
#  'figures': [{'full': 'https://patentimages.storage.googleapis.com/19/6c/bc/048fd2c49ae6f4/HDA0000083765650000011.png',
#               'thumbnail': 'https://patentimages.storage.googleapis.com/0d/66/9b/58ad3b75c0a552/HDA0000083765650000011.png'},
#              {'full': 'https://patentimages.storage.googleapis.com/47/87/a8/a567aebfc29130/HDA0000083765650000021.png',
#               'thumbnail': 'https://patentimages.storage.googleapis.com/f0/74/b7/391a322a8540e9/HDA0000083765650000021.png'},
#              {'full': 'https://patentimages.storage.googleapis.com/2b/4f/3f/3447bff93f1a67/HDA0000083765650000031.png',
#               'thumbnail': 'https://patentimages.storage.googleapis.com/c0/1b/b5/83e73db6c4ee1e/HDA0000083765650000031.png'}],
#  'filing_date': '2010-02-16',
#  'inventor': '奈杰尔·沃勒',
#  'language': 'en',
#  'patent_id': 'patent/CN102318164A/en',
#  'patent_link': 'https://patents.google.com/patent/CN102318164A/en',
#  'pdf': 'https://patentimages.storage.googleapis.com/80/83/b9/6cd71c8a43bc2c/CN102318164A.pdf',
#  'position': 3,
#  'priority_date': '2009-02-16',
#  'publication_date': '2012-01-11',
#  'publication_number': 'CN102318164A',
#  'rank': 2,
#  'serpapi_link': 'https://serpapi.com/search.json?engine=google_patents_details&patent_id=patent%2FCN102318164A%2Fen',
#  'snippet': 'Disclosed is a self-charging mobile handset. Access to mobile '
#             'phones plays a key part in poverty reduction; however there are '
#             'over 1.6 billion people who do not have direct access to '
#             'electricity to charge mobile phones in Sub-Sahara Africa and '
#             'South Asia. People in these countries may spend up to …',
#  'thumbnail': 'https://patentimages.storage.googleapis.com/a0/fb/f5/ab66ff65c16026/HDA0000083765650000011.png',
#  'title': 'Self-charging ultra low cost mobile handset'}
# Skipping: System and apparatus for device to device charging with date 2009-01-22
# Skipping: Personal base station of mobile phone with date 2012-04-25
# Skipping: Self-charging ultra low cost mobile handset with date 2012-01-11
# Skipping: Handset device possessing function of talk back, and battery with date 2007-12-26
# Skipping: Bluetooth gloves with date 2011-05-25
# Skipping: On -vehicle supplementary display device with date 2016-03-02
# Skipping: Negative electrode plate, battery and electronic equipment with date 2023-05-09
# Skipping: Seti5500 wired / wireless phone with date 2000-06-15
# Skipping: Battery and electronic equipment with date 2024-01-16
# Skipping: How to save battery in mobile terminal with date 2006-12-27
# Skipping: Satellite telephone with date 2024-01-05
# Skipping: Solid-state battery, method for manufacturing solid-state battery, vehicle, … with date 2022-07-08
# Skipping: Wireless fixed-line telephone and mobile phone association method with date 2022-02-15
# Skipping: Digital cordless telephone provided with wireless communication module with date 2011-09-21
# Skipping: In-vehicle mobile wireless communication device with date 1992-03-16
# Skipping: Mobile station, electric charging device and handsfree set for automobile with date 2001-11-23
# Skipping: No screen mobile phone with date 2008-09-17
# Skipping: Automatic telephone network selection system with date 2004-03-04
# Skipping: Mobile phone with date 2000-10-10
# Skipping: Dual-chip mobile phone with date 2005-01-05
# Skipping: Watchband solar cell wireless telephone and mobile phone with date 2006-11-08
# Skipping: The structure of antenna, RF transceiver, battery, charging terminal of … with date 2005-02-28
# Skipping: Smart battery with integrated sensing and electronics with date 2022-07-01
# Skipping: Mobile terminal and manufacturing method for heat spreader module with date 2018-01-23
# Skipping: Prismatic battery cell having two or more case members with date 2020-09-08
# Skipping: Bluetooth connection method and device with date 2020-06-04
# Skipping: Method of manufacturing electronic devices with date 2023-09-28
# Skipping: Power storage device and electronic equipment with date 2021-11-02
# Skipping: Battery cell, battery and power consumption device with date 2022-03-08
# Skipping: Current collector for secondary battery with date 2023-05-19
# Skipping: Bluetooth connection method, device and system with date 2020-10-22
# Skipping: Thin Film Transistor and Manufacturing Method, Memory and Manufacturing Method, … with date 2023-11-16
# Skipping: Voice recognition method, wearable device and electronic device with date 2023-12-20
# Skipping: Batteries, battery packs, electronic devices, electric vehicles, power storage … with date 2020-11-25
# Skipping: secondary battery with date 2024-02-28
# Skipping: In-ear wireless listening device with date 2021-04-27
# Skipping: Method of manufacturing a battery electrode with date 2024-03-21
# Skipping: Wireless earphone case and system with date 2021-08-26
# Skipping: Secondary battery with date 2022-02-04
# Skipping: Positive-electrode active material, positive electrode, battery, battery pack, … with date 2021-12-01
# Skipping: Lithium-supplement layer and its negative electrode sheet, lithium ion battery … with date 2023-10-03
# Skipping: Method for manufacturing electrode layer and method for manufacturing power … with date 2023-10-24
# 8 recent patents saved to patents.json

# %%
#  Embed with Gemini
import google.generativeai as genai
import numpy as np
import faiss
import json

# Configure Gemini
genai.configure(api_key=gemini_api_key)
embedding_model = "models/embedding-001"

#  Load patents data from the saved file
with open("patents.json", "r") as f:
    patents = json.load(f)

# Generate document embeddings
abstracts = [p["abstract"] for p in patents]

abstract_embeddings = []
valid_patents = []  # to track which patents got embedded
for i, text in enumerate(abstracts):
    if not text.strip():
        continue
    try:
        emb = genai.embed_content(
            model=embedding_model,
            content=text,
            task_type="retrieval_document"
        )["embedding"]
        abstract_embeddings.append(emb)
        valid_patents.append(patents[i])
    except Exception as e:
        print(f"Embedding failed for abstract {i + 1}: {text[:50]}... | Error: {e}")
        continue


abstract_embeddings = np.array(abstract_embeddings)

#  Store in FAISS
dimension = len(abstract_embeddings[0])
index = faiss.IndexFlatL2(dimension)
index.add(abstract_embeddings)

print(" FAISS index created using Gemini embeddings.")
# Out:
#  FAISS index created using Gemini embeddings.

# %%
#  Query embedding
query = f"What all new technologies/innovations to focus on, related to {topic} in {industry}?"

query_embedding = genai.embed_content(
    model=embedding_model,
    content=query,
    task_type="retrieval_query"
)["embedding"]

#  Search FAISS
D, I = index.search(np.array([query_embedding]), 10)
top_patents = [valid_patents[i] for i in I[0]]
print(f" Retrieved {len(top_patents)} patents for trend analysis.")
# Out:
#  Retrieved 10 patents for trend analysis.

# %%
# 📦 Import and configure Gemini API
import google.generativeai as genai

genai.configure(api_key=gemini_api_key)  # Set your Gemini API key here

#  Agent 2: TrendAnalyzer
class TrendAnalyzer:
    def __init__(self):
        # Initialize the Gemini Pro model
        self.model = genai.GenerativeModel(model_name="gemini-1.5-pro")

    def analyze(self, patents, industry, topic):
        # Prepare context from the top 5 patents
        context = ""
        for p in patents[:5]:
            # Skip if abstract is missing or too short
            # Remove strict abstract length filter
            if not p["abstract"].strip():
                continue

            # Truncate after 500 chars if needed
            abstract = p["abstract"][:500] + ("..." if len(p["abstract"]) > 500 else "")


            # Format the patent details for prompt
            context += f"""
    Patent Title: {p['title']}
    Assignee: {p['assignee']}
    Publication Date: {p['publication_date']}
    Abstract: {abstract}

    """

        prompt = f"""
        You are a top-tier patent analyst. The following are recent patents in the '{industry}' sector related to '{topic}'.

        Analyze and return:

        1. 🔍 **Top 5 Patents** - Each with:
            - Title
            - Assignee
            - Publication Date
            - Abstract (summarized in 1-2 lines)

        2. 🚀 **Emerging Innovations (5)** - Identify and briefly describe novel technologies evident from the patents.

        3. 📊 **Trend Summary (max 100 words)** - What's the emerging direction in this domain?

        4. 🧪 **R&D Suggestions** - Suggest 3 actionable ideas for phone manufacturers based on these findings.

        Patent Data:
        {context}
        """



        # Send the prompt to Gemini and return the response text
        response = self.model.generate_content(prompt)
        return response.text

# %%
analyzer = TrendAnalyzer()
summary = analyzer.analyze(top_patents, industry, topic)
print(summary)
# Out:
# ## Mobile Phone Battery Technology Patent Analysis
#
# **1. 🔍 Top 5 Patents:**
#
# 1. **Title:** Flexible battery and preparation method thereof
#     **Assignee:** Huawei Technologies Co., Ltd.
#     **Publication Date:** 2025-03-06
#     **Abstract:** A flexible battery with an energy-absorbing layer between the electrochemical cell and wrapping layer for enhanced safety and durability.
#
# 2. **Title:** A band with a built-in curvable battery
#     **Assignee:** 日商半導體能源研究所股份有限公司
#     **Publication Date:** 2024-10-11
#     **Abstract:** A bendable, high-capacity battery utilizing a periodically waved film exterior for wearables.
#
# 3. **Title:** Positive electrode active material, method for producing same, positive …
#     **Assignee:** 컨템포러리 엠퍼렉스 테크놀로지 (홍콩) 리미티드
#     **Publication Date:** 2024-10-21
#     **Abstract:**  A novel positive electrode active material and manufacturing method for improved lithium-ion battery performance.
#
# 4. **Title:** Negative electrode material, composite negative electrode material and …
#     **Assignee:** 华为技术有限公司
#     **Publication Date:** 2024-09-24
#     **Abstract:** A composite negative electrode material with a core and coating layer for enhanced secondary battery performance.
#
# 5. **Title:** Battery cell, battery, electric equipment and manufacturing method and …
#     **Assignee:** 江苏时代新能源科技有限公司
#     **Publication Date:** 2024-06-07
#     **Abstract:**  A new battery cell design, including case, electrode assembly, end cap, and current collector, focusing on improved manufacturing methods.
#
#
# **2. 🚀 Emerging Innovations:**
#
# 1. **Flexible Batteries with Enhanced Safety:** Integration of energy-absorbing layers within flexible batteries improves safety and durability, paving the way for foldable and wearable devices.
# 2. **Curvable Batteries for Wearables:**  Batteries designed with wave-shaped exteriors allow for bending and integration into wearables like bands.
# 3. **Advanced Electrode Materials:**  Research focuses on novel positive and negative electrode materials and their manufacturing processes to enhance battery capacity, lifespan, and charging speed.
# 4. **Improved Battery Cell Design and Manufacturing:** New battery cell structures and manufacturing techniques are being developed for better performance and efficiency.
# 5. **Focus on Solid-State Batteries (Implied):** While not explicitly mentioned in these patents, the emphasis on flexibility and safety suggests a move towards solid-state technology, which inherently offers these advantages.
#
# **3. 📊 Trend Summary:**
#
# The mobile phone battery sector is heavily focused on flexibility, safety, and improved performance.  Research targets novel electrode materials, cell designs, and manufacturing processes to enhance energy density, charging speeds, and lifespan.  The emergence of flexible and curvable batteries specifically caters to the growing demand for wearable devices and foldable phones.  Enhanced safety features are crucial for broader adoption of these new form factors.
#
# **4. 🧪 R&D Suggestions:**
#
# 1. **Investigate solid-state electrolytes compatible with flexible battery designs:** This could significantly enhance safety and energy density, enabling truly flexible and foldable phones.
# 2. **Optimize energy-absorbing layers for impact and puncture resistance:** This would address safety concerns related to flexible batteries and broaden their application in various devices.
# 3. **Explore new manufacturing processes for scalable production of flexible batteries:** This is crucial for commercializing these innovative battery technologies and meeting market demand.

# %%
# ✅ BONUS: Generate WordCloud from the retrieved patent abstracts
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all abstracts into a single string
text = " ".join(p["abstract"] for p in top_patents if p["abstract"].strip())

# Create and configure the word cloud
wordcloud = WordCloud(width=1000, height=500, background_color='white', colormap='viridis').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Frequently Occurring Words in Patent Abstracts", fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-235d65938c50> in <cell line: 0>()
#       4
#       5 # Combine all abstracts into a single string
# ----> 6 text = " ".join(p["abstract"] for p in top_patents if p["abstract"].strip())
#       7
#       8 # Create and configure the word cloud
#
# NameError: name 'top_patents' is not defined
